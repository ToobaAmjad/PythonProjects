# %% [markdown]
# ![](download.jpg)

# %%
dataset_1=[1,3,5]
dataset_2=[2,4,6]
import pandas as pd
series1= pd.Series(dataset_1)
series2= pd.Series(dataset_2)
S=series1 + series2
S
# Out:
# 0     3
# 1     7
# 2    11
# dtype: int64

# %%
Data1 = {"apple":[2], "orange":[5]}
import pandas as pd
package = pd.DataFrame(Data1)
package
# Out:
#    apple  orange
# 0      2       5

# %%
import pandas as pd
purchase= pd.DataFrame(data, index= ["rob", "david", "haana"])
purchase
# Out:
#        apple  orange
# rob        2       5
# david      2       5
# haana      2       5

# %%
purchase.loc['david']
# Out:
# apple     2
# orange    5
# Name: david, dtype: int64

# %%
import pandas as pd
matches_df1 = pd.read_csv("example.csv")
matches_df1
# Out:
#           Year       Institutional_sector_name  Institutional_sector_code  \
# 0      2008.03  Corporate business enterprises                        141
# 1      2009.03  Corporate business enterprises                        141
# 2      2010.03  Corporate business enterprises                        141
# 3      2011.03  Corporate business enterprises                        141
# 4      2012.03  Corporate business enterprises                        141
# ...        ...                             ...                        ...
# 18715  2013.03                   Pension funds                        261
# 18716  2014.03                   Pension funds                        261
# 18717  2015.03                   Pension funds                        261
# 18718  2016.03                   Pension funds                        261
# 18719  2017.03                   Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# ...

# %%
import numpy as np
a = np.array(42)

b = np.array([1, 2, 3, 4, 5])

c = np.array([[1, 2, 3], [4, 5, 6]])

d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])



print(a.ndim)

print(b.ndim)

print(c.ndim)

print(d.ndim)

print (d)
print (type(a))
# Out:
# 0
# 1
# 2
# 3
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]
# <class 'numpy.ndarray'>
